# %% [markdown]
# ## pandas_profilling

# %%
import pandas as  pd
from pandas_profiling import ProfileReport
train = pd.read_csv('./birdsong/train.csv')

# %%
train
# Out:
#        rating playback_used ebird_code    channels        date          pitch  \
# 0         3.5            no     aldfly    1 (mono)  2013-05-25  Not specified
# 1         4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 2         4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 3         3.5            no     aldfly  2 (stereo)  2013-05-27           both
# 4         4.0            no     aldfly  2 (stereo)  2013-05-27           both
# ...       ...           ...        ...         ...         ...            ...
# 21370     4.5            no     yetvir    1 (mono)  2019-05-15           both
# 21371     3.5            no     yetvir    1 (mono)  2017-05-14  Not specified
# 21372     5.0            no     yetvir    1 (mono)  2017-06-10  Not specified
# 21373     3.5            no     yetvir  2 (stereo)  2009-05-06          level
# 21374     3.5            no     yetvir  2 (stereo)  2010-06-09          level
#
#        duration      filename          speed                species  ...  \
# 0            25  XC134874.mp3  Not specified       Alder Flycatcher  ...
# 1            36  XC135454.mp3           both       Alder Flycatcher  ...
# 2            39  XC135455.mp3           both       Alder Flycatcher  ...
# 3            33  XC135456.mp3           both       Alder Flycatcher  ...
# 4            36  XC135457.mp3          level       Alder Flycatcher  ...
# ...         ...           ...            ...                    ...  ...
# 21370        28  XC477608.mp3          level  Yellow-throated Vireo  ...
# 21371        52  XC500348.mp3  Not specified  Yellow-throated Vireo  ...
# 21372        96  XC501230.mp3  Not specified  Yellow-throated Vireo  ...
# 21373        35   XC54828.mp3          level  Yellow-throated Vireo  ...
# 21374       103   XC55761.mp3          level  Yellow-throated Vireo  ...
#
#         xc_id                                url        country  \
# 0      134874  https://www.xeno-canto.org/134874  United States
# 1      135454  https://www.xeno-canto.org/135454  United States
# 2      135455  https://www.xeno-canto.org/135455  United States
# 3      135456  https://www.xeno-canto.org/135456  United States
# 4      135457  https://www.xeno-canto.org/135457  United States
# ...       ...                                ...            ...
# 21370  477608  https://www.xeno-canto.org/477608  United States
# 21371  500348  https://www.xeno-canto.org/500348  United States
# 21372  501230  https://www.xeno-canto.org/501230  United States
# 21373   54828   https://www.xeno-canto.org/54828  United States
# 21374   55761   https://www.xeno-canto.org/55761  United States
#
#                  author                           primary_label longitude  \
# 0      Jonathon Jongsma      Empidonax alnorum_Alder Flycatcher   -92.962
# 1           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# 2           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# 3           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# 4           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# ...                 ...                                     ...       ...
# 21370         Sue Riffe  Vireo flavifrons_Yellow-throated Vireo  -84.0131
# 21371     Jacob Saucier  Vireo flavifrons_Yellow-throated Vireo  -77.3422
# 21372     Jacob Saucier  Vireo flavifrons_Yellow-throated Vireo  -77.3422
# 21373       Mike Nelson  Vireo flavifrons_Yellow-throated Vireo  -83.9462
# 21374       Mike Nelson  Vireo flavifrons_Yellow-throated Vireo  -83.5409
#
#               length     time         recordist  \
# 0      Not specified     8:00  Jonathon Jongsma
# 1             0-3(s)    08:30       Mike Nelson
# 2             0-3(s)    08:30       Mike Nelson
# 3             0-3(s)    08:30       Mike Nelson
# 4             0-3(s)    08:30       Mike Nelson
# ...              ...      ...               ...
# 21370         0-3(s)    13:00         Sue Riffe
# 21371  Not specified    15:00     Jacob Saucier
# 21372  Not specified    13:30     Jacob Saucier
# 21373         >10(s)   9:45am       Mike Nelson
# 21374         >10(s)  11:30am       Mike Nelson
#
#                                                  license
# 0            Creative Commons Attribution-ShareAlike 3.0
# 1      Creative Commons Attribution-NonCommercial-Sha...
# 2      Creative Commons Attribution-NonCommercial-Sha...
# 3      Creative Commons Attribution-NonCommercial-Sha...
# 4      Creative Commons Attribution-NonCommercial-Sha...
# ...                                                  ...
# 21370  Creative Commons Attribution-NonCommercial-Sha...
# 21371  Creative Commons Attribution-NonCommercial-Sha...
# 21372  Creative Commons Attribution-NonCommercial-Sha...
# 21373  Creative Commons Attribution-NonCommercial-Sha...
# 21374  Creative Commons Attribution-NonCommercial-Sha...
#
# [21375 rows x 35 columns]

# %%
#train.profile_report()
# 윈도우에서 동작 안함, 리눅스에서는 동작함

# %% [markdown]
# ## dabl

# %%
import pandas as pd
import dabl
df = pd.read_csv("./house-prices-advanced-regression-techniques/train.csv")

# %%
df_clean = dabl.clean(df, verbose=0)
# Out:
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\preprocessing.py:318: UserWarning: Discarding near-constant features: ['Street', 'Utilities', 'Condition2', 'RoofMatl', 'Heating', 'LowQualFinSF', 'KitchenAbvGr', 'GarageQual', 'GarageCond', '3SsnPorch', 'PoolArea', 'MiscVal']
#   near_constant.index[near_constant].tolist()))

# %%
types = dabl.detect_types(df_clean)
print(types)
# Out:
#                continuous  dirty_float  low_card_int  categorical   date  \
# MSSubClass          False        False          True        False  False
# MSZoning            False        False         False         True  False
# LotFrontage          True        False         False        False  False
# LotArea              True        False         False        False  False
# Alley               False        False         False         True  False
# ...                   ...          ...           ...          ...    ...
# MoSold              False        False          True        False  False
# YrSold              False        False         False         True  False
# SaleType            False        False         False         True  False
# SaleCondition       False        False         False         True  False
# SalePrice            True        False         False        False  False
#
#                free_string  useless
# MSSubClass           False    False
# MSZoning             False    False
# LotFrontage          False    False
# LotArea              False    False
# Alley                False    False
# ...                    ...      ...
# MoSold               False    False
# YrSold               False    False
# SaleType             False    False
# SaleCondition        False    False
# SalePrice            False    False
#
# [68 rows x 7 columns]

# %%
dabl.plot(df, 'SalePrice')
# Out:
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\plot\supervised.py:528: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   FutureWarning)
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\preprocessing.py:318: UserWarning: Discarding near-constant features: ['Street', 'Utilities', 'Condition2', 'RoofMatl', 'Heating', 'LowQualFinSF', 'KitchenAbvGr', 'GarageQual', 'GarageCond', '3SsnPorch', 'PoolArea', 'MiscVal']
#   near_constant.index[near_constant].tolist()))
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 3 outliers in column GrLivArea.
#   int(dropped), series.name), UserWarning)
# Target looks like regression
# Showing only top 10 of 22 continuous features
# Showing only top 10 of 45 categorical features
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 1 outliers in column TotalBsmtSF.
#   int(dropped), series.name), UserWarning)
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 3 outliers in column 1stFlrSF.
#   int(dropped), series.name), UserWarning)
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\plot\utils.py:621: UserWarning: Dropped 2 outliers in column MasVnrArea.
#   int(dropped), series.name), UserWarning)

# %%
ec = dabl.SimpleClassifier(random_state=0).fit(df, target_col="SalePrice")
# Out:
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\dabl\preprocessing.py:318: UserWarning: Discarding near-constant features: ['Street', 'Utilities', 'Condition2', 'RoofMatl', 'Heating', 'LowQualFinSF', 'KitchenAbvGr', 'GarageQual', 'GarageCond', '3SsnPorch', 'PoolArea', 'MiscVal']
#   near_constant.index[near_constant].tolist()))
# c:\users\juhyeong\anaconda3\envs\tftorch\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Running DummyClassifier(strategy='prior')
# accuracy: 0.014 recall_macro: 0.004 precision_macro: 0.000 f1_macro: 0.000
# === new best DummyClassifier(strategy='prior') (using recall_macro):
# accuracy: 0.014 recall_macro: 0.004 precision_macro: 0.000 f1_macro: 0.000
#
# Running GaussianNB()
# accuracy: 0.015 recall_macro: 0.008 precision_macro: 0.003 f1_macro: 0.004
# === new best GaussianNB() (using recall_macro):
# accuracy: 0.015 recall_macro: 0.008 precision_macro: 0.003 f1_macro: 0.004
#
# Running MultinomialNB()
# accuracy: 0.019 recall_macro: 0.008 precision_macro: 0.003 f1_macro: 0.003
# === new best MultinomialNB() (using recall_macro):
# accuracy: 0.019 recall_macro: 0.008 precision_macro: 0.003 f1_macro: 0.003
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.010 recall_macro: 0.004 precision_macro: 0.000 f1_macro: 0.000
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=663)
# accuracy: 0.005 recall_macro: 0.002 precision_macro: 0.002 f1_macro: 0.002
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.010 recall_macro: 0.004 precision_macro: 0.000 f1_macro: 0.000
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000)
# accuracy: 0.003 recall_macro: 0.002 precision_macro: 0.001 f1_macro: 0.001
# Running LogisticRegression(class_weight='balanced', max_iter=1000)
# accuracy: 0.012 recall_macro: 0.007 precision_macro: 0.004 f1_macro: 0.005
#
# Best model:
# Pipeline(steps=[('minmaxscaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('multinomialnb', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])
# Best Scores:
# accuracy: 0.019 recall_macro: 0.008 precision_macro: 0.003 f1_macro: 0.003

# %% [markdown]
# ## datasist

# %%
import pandas as pd
import datasist as ds
import numpy as np

train_df = pd.read_csv('./house-prices-advanced-regression-techniques/train.csv')
test_df = pd.read_csv('./house-prices-advanced-regression-techniques/test.csv')

# %%
ds.structdata.check_train_test_set(train_df, test_df, index=None, col=None)
# Out:
# There are 1460 training rows and 1459 test rows.
# There are 81 training columns and 80 test columns.

# %%
ds.structdata.describe(train_df)
# Out:
# First five data points
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]
# Random five data points
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 372  373         120       RL         50.0     7175   Pave   NaN      Reg
# 50    51          60       RL          NaN    13869   Pave   NaN      IR2
# 572  573          60       RL         83.0    13159   Pave   NaN      IR1
# 671  672          70       RH         54.0     6629   Pave   NaN      Reg
# 583  584          75       RM         75.0    13500   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 372         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 50          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 572         HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 671         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 583         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 372      2   2010        WD         Normal     125000
# 50       7   2007        WD         Normal     177000
# 572      7   2009       New        Partial     224500
# 671      7   2009        WD         Normal     103600
# 583      7   2008        WD         Normal     325000
#
# [5 rows x 81 columns]
# Last five data points
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]
# Shape of  data set: (1460, 81)
#
#
# Size of  data set: 118260
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#               Data Type
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage     float64
# LotArea           int64
# ...                 ...
# MoSold            int64
# YrSold            int64
# SaleType         object
# SaleCondition    object
# SalePrice         int64
#
# [81 rows x 1 columns]
# Numerical Features in Data set
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
#
#
# Categorical Features in Data set
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']
# Statistical Description of Columns
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]
# Description of Categorical Features
#               count unique      top  freq
# MSZoning       1460      5       RL  1151
# Street         1460      2     Pave  1454
# Alley            91      2     Grvl    50
# LotShape       1460      4      Reg   925
# LandContour    1460      4      Lvl  1311
# Utilities      1460      2   AllPub  1459
# LotConfig      1460      5   Inside  1052
# LandSlope      1460      3      Gtl  1382
# Neighborhood   1460     25    NAmes   225
# Condition1     1460      9     Norm  1260
# Condition2     1460      8     Norm  1445
# BldgType       1460      5     1Fam  1220
# HouseStyle     1460      8   1Story   726
# RoofStyle      1460      6    Gable  1141
# RoofMatl       1460      8  CompShg  1434
# Exterior1st    1460     15  VinylSd   515
# Exterior2nd    1460     16  VinylSd   504
# MasVnrType     1452      4     None   864
# ExterQual      1460      4       TA   906
# ExterCond      1460      5       TA  1282
# Foundation     1460      6    PConc   647
# BsmtQual       1423      4       TA   649
# BsmtCond       1423      4       TA  1311
# BsmtExposure   1422      4       No   953
# BsmtFinType1   1423      6      Unf   430
# BsmtFinType2   1422      6      Unf  1256
# Heating        1460      6     GasA  1428
# HeatingQC      1460      5       Ex   741
# CentralAir     1460      2        Y  1365
# Electrical     1459      5    SBrkr  1334
# KitchenQual    1460      4       TA   735
# Functional     1460      7      Typ  1360
# FireplaceQu     770      5       Gd   380
# GarageType     1379      6   Attchd   870
# GarageFinish   1379      3      Unf   605
# GarageQual     1379      5       TA  1311
# GarageCond     1379      5       TA  1326
# PavedDrive     1460      3        Y  1340
# PoolQC            7      3       Gd     3
# Fence           281      4    MnPrv   157
# MiscFeature      54      4     Shed    49
# SaleType       1460      9       WD  1267
# SaleCondition  1460      6   Normal  1198
# Unique class Count of Categorical features
# <style  type="text/css" >
#     #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.0%, transparent 36.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 60.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.0%, transparent 64.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_470f515a_c7ef_11ea_93b2_00d861d0fab3row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%
# Missing Values in Data
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               0              0.0
# 3     LotFrontage             259             17.7
# 4         LotArea               0              0.0
# ..            ...             ...              ...
# 76         MoSold               0              0.0
# 77         YrSold               0              0.0
# 78       SaleType               0              0.0
# 79  SaleCondition               0              0.0
# 80      SalePrice               0              0.0
#
# [81 rows x 3 columns]

# %%
ds.structdata.describe(test_df)
# Out:
# First five data points
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]
# Random five data points
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 316   1777          30       RL         80.0     8480   Pave   NaN      Reg
# 982   2443          30       RM         60.0     7200   Pave   NaN      Reg
# 34    1495          60       RL         88.0    11134   Pave   NaN      Reg
# 1388  2849          60       RL         70.0     8726   Pave   NaN      Reg
# 1260  2721          20       RL         80.0     9600   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 316          Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 982          Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 34           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1388         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1260         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition
# 316        0      8    2009        WD         Normal
# 982        0      5    2007        WD         Normal
# 34         0      6    2010        WD         Normal
# 1388       0      9    2006        WD         Normal
# 1260       0      7    2006        WD         Normal
#
# [5 rows x 80 columns]
# Last five data points
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [5 rows x 80 columns]
# Shape of  data set: (1459, 80)
#
#
# Size of  data set: 116720
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#               Data Type
# Id                int64
# MSSubClass        int64
# MSZoning         object
# LotFrontage     float64
# LotArea           int64
# ...                 ...
# MiscVal           int64
# MoSold            int64
# YrSold            int64
# SaleType         object
# SaleCondition    object
#
# [80 rows x 1 columns]
# Numerical Features in Data set
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
#
#
# Categorical Features in Data set
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']
# Statistical Description of Columns
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# min       1.000000  1879.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1953.000000   1963.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1992.000000     0.000000   350.500000  ...
# 75%       6.000000  2001.000000   2004.000000   164.000000   753.500000  ...
# max       9.000000  2010.000000   2010.000000  1290.000000  4010.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1458.000000  1459.000000  1459.000000    1459.000000  1459.000000
# mean    472.768861    93.174777    48.313914      24.243317     1.794380
# std     217.048611   127.744882    68.883364      67.227765    20.207842
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     318.000000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    28.000000       0.000000     0.000000
# 75%     576.000000   168.000000    72.000000       0.000000     0.000000
# max    1488.000000  1424.000000   742.000000    1012.000000   360.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean     17.064428     1.744345     58.167923     6.104181  2007.769705
# std      56.609763    30.491646    630.806978     2.722432     1.301740
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
# [8 rows x 37 columns]
# Description of Categorical Features
#               count unique      top  freq
# MSZoning       1455      5       RL  1114
# Street         1459      2     Pave  1453
# Alley           107      2     Grvl    70
# LotShape       1459      4      Reg   934
# LandContour    1459      4      Lvl  1311
# Utilities      1457      1   AllPub  1457
# LotConfig      1459      5   Inside  1081
# LandSlope      1459      3      Gtl  1396
# Neighborhood   1459     25    NAmes   218
# Condition1     1459      9     Norm  1251
# Condition2     1459      5     Norm  1444
# BldgType       1459      5     1Fam  1205
# HouseStyle     1459      7   1Story   745
# RoofStyle      1459      6    Gable  1169
# RoofMatl       1459      4  CompShg  1442
# Exterior1st    1458     13  VinylSd   510
# Exterior2nd    1458     15  VinylSd   510
# MasVnrType     1443      4     None   878
# ExterQual      1459      4       TA   892
# ExterCond      1459      5       TA  1256
# Foundation     1459      6    PConc   661
# BsmtQual       1415      4       TA   634
# BsmtCond       1414      4       TA  1295
# BsmtExposure   1415      4       No   951
# BsmtFinType1   1417      6      GLQ   431
# BsmtFinType2   1417      6      Unf  1237
# Heating        1459      4     GasA  1446
# HeatingQC      1459      5       Ex   752
# CentralAir     1459      2        Y  1358
# Electrical     1459      4    SBrkr  1337
# KitchenQual    1458      4       TA   757
# Functional     1457      7      Typ  1357
# FireplaceQu     729      5       Gd   364
# GarageType     1383      6   Attchd   853
# GarageFinish   1381      3      Unf   625
# GarageQual     1381      4       TA  1293
# GarageCond     1381      5       TA  1328
# PavedDrive     1459      3        Y  1301
# PoolQC            3      2       Ex     2
# Fence           290      4    MnPrv   172
# MiscFeature      51      3     Shed    46
# SaleType       1458      9       WD  1258
# SaleCondition  1459      6   Normal  1204
# Unique class Count of Categorical features
# <style  type="text/css" >
#     #T_47350210_c7ef_11ea_ba25_00d861d0fab3row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.0%, transparent 36.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.0%, transparent 56.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.0%, transparent 64.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_47350210_c7ef_11ea_ba25_00d861d0fab3row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%
# Missing Values in Data
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               4              0.3
# 3     LotFrontage             227             15.6
# 4         LotArea               0              0.0
# ..            ...             ...              ...
# 75        MiscVal               0              0.0
# 76         MoSold               0              0.0
# 77         YrSold               0              0.0
# 78       SaleType               1              0.1
# 79  SaleCondition               0              0.0
#
# [80 rows x 3 columns]

# %%
numerical_feats = ds.structdata.get_num_feats(train_df)
ds.structdata.detect_outliers(train_df,80,numerical_feats)
# Out:
# []

# %%
ds.structdata.display_missing(train_df)
# Out:
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               0              0.0
# 3     LotFrontage             259             17.7
# 4         LotArea               0              0.0
# ..            ...             ...              ...
# 76         MoSold               0              0.0
# 77         YrSold               0              0.0
# 78       SaleType               0              0.0
# 79  SaleCondition               0              0.0
# 80      SalePrice               0              0.0
#
# [81 rows x 3 columns]

# %%
ds.structdata.display_missing(test_df)
# Out:
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               4              0.3
# 3     LotFrontage             227             15.6
# 4         LotArea               0              0.0
# ..            ...             ...              ...
# 75        MiscVal               0              0.0
# 76         MoSold               0              0.0
# 77         YrSold               0              0.0
# 78       SaleType               1              0.1
# 79  SaleCondition               0              0.0
#
# [80 rows x 3 columns]

# %%
cat_feats = ds.structdata.get_cat_feats(train_df)
cat_feats
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
num_feats = ds.structdata.get_num_feats(train_df)
num_feats
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
get_unique_counts = ds.structdata.get_unique_counts(train_df)
get_unique_counts
# Out:
# <style  type="text/css" >
#     #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.0%, transparent 36.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 32.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 60.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.0%, transparent 64.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 28.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_4747931a_c7ef_11ea_bafd_00d861d0fab3row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%

# %%
ds.visualizations.autoviz(train_df)
# Out:
# Imported AutoViz_Class version: 0.0.68. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
#
# To remove previous versions, perform 'pip uninstall autoviz'
# Shape of your Data Set: (1460, 81)
# Classifying variables in data set...
#     81 Predictors classified...
#         This does not include the Target column(s)
#     4 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 6
# Could not draw Distribution Plot
# Could not draw Date Vars
# Number of Categorical and Continuous Vars exceeds limit, hence no Bar Plots
# Time to run AutoViz (in seconds) = 0.944

# %%
all_data, ntrain, ntest = ds.structdata.join_train_and_test(train_df, test_df)
print("New size of combined data {}".format(all_data.shape))
print("Old size of train data: {}".format(ntrain))
print("Old size of test data: {}".format(ntest))

#later splitting after transformations
train = all_data[:ntrain]
test = all_data[ntrain:]
# Out:
# New size of combined data (2919, 81)
# Old size of train data: 1460
# Old size of test data: 1459

# %%
new_train_df = ds.feature_engineering.drop_missing(train_df,  
                                                    percent=7.0)
ds.structdata.display_missing(new_train_df)
# Out:
# Dropped ['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               0              0.0
# 3         LotArea               0              0.0
# 4          Street               0              0.0
# ..            ...             ...              ...
# 70         MoSold               0              0.0
# 71         YrSold               0              0.0
# 72       SaleType               0              0.0
# 73  SaleCondition               0              0.0
# 74      SalePrice               0              0.0
#
# [75 rows x 3 columns]

# %%
ds.feature_engineering.drop_redundant(new_train_df)
# Out:
# Dropped []
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0       AllPub    Inside       Gtl  ...             0         0           0
# 1       AllPub       FR2       Gtl  ...             0         0           0
# 2       AllPub    Inside       Gtl  ...             0         0           0
# 3       AllPub    Corner       Gtl  ...           272         0           0
# 4       AllPub       FR2       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 1455    AllPub    Inside       Gtl  ...             0         0           0
# 1456    AllPub    Inside       Gtl  ...             0         0           0
# 1457    AllPub    Inside       Gtl  ...             0         0           0
# 1458    AllPub    Inside       Gtl  ...           112         0           0
# 1459    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0           0       0       2    2008        WD         Normal    208500
# 1           0       0       5    2007        WD         Normal    181500
# 2           0       0       9    2008        WD         Normal    223500
# 3           0       0       2    2006        WD        Abnorml    140000
# 4           0       0      12    2008        WD         Normal    250000
# ...       ...     ...     ...     ...       ...            ...       ...
# 1455        0       0       8    2007        WD         Normal    175000
# 1456        0       0       2    2010        WD         Normal    210000
# 1457        0    2500       5    2010        WD         Normal    266500
# 1458        0       0       4    2010        WD         Normal    142125
# 1459        0       0       6    2008        WD         Normal    147500
#
# [1460 rows x 75 columns]

# %%
df = ds.feature_engineering.fill_missing_cats(train_df)
ds.structdata.display_missing(df)
# Out:
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               0              0.0
# 3     LotFrontage             259             17.7
# 4         LotArea               0              0.0
# ..            ...             ...              ...
# 76         MoSold               0              0.0
# 77         YrSold               0              0.0
# 78       SaleType               0              0.0
# 79  SaleCondition               0              0.0
# 80      SalePrice               0              0.0
#
# [81 rows x 3 columns]

# %%
df = ds.feature_engineering.fill_missing_num(train_df)
ds.structdata.display_missing(df)
# Out:
#          features  missing_counts  missing_percent
# 0              Id               0              0.0
# 1      MSSubClass               0              0.0
# 2        MSZoning               0              0.0
# 3     LotFrontage               0              0.0
# 4         LotArea               0              0.0
# ..            ...             ...              ...
# 76         MoSold               0              0.0
# 77         YrSold               0              0.0
# 78       SaleType               0              0.0
# 79  SaleCondition               0              0.0
# 80      SalePrice               0              0.0
#
# [81 rows x 3 columns]

# %%
df = ds.feature_engineering.fill_missing_num(df)
df = ds.feature_engineering.log_transform(df,columns=['Id'])
